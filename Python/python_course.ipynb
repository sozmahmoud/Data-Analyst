# %%
x=z=y='root'
print(z)
print(y)
print(x)
# Out:
# root
# root
# root

# %%
fruit=['pineaaple','apple','peach']
x,z,s=fruit
print(x)
print(z)
print(s)
# Out:
# pineaaple
# apple
# peach

# %%
1==1
# Out:
# True

# %%
multi_line="""
soz graduated from tci college 2026
"""
print(multi_line)
# Out:
# soz graduated from tci college 2026

# %%
a="hospital"
print(a[3:4])
# Out:
# p

# %%
a="hospital"
print(a[3:6])
# Out:
# pit

# %%
a="hospital"
print(a[0])
# Out:
# h

# %%
fruit=['pineaaple','apple','peach']
fruit.append('grapes')
print(fruit)
# Out:
# ['pineaaple', 'apple', 'peach', 'grapes']

# %%
set1={1,2,3}
set2={3,4,5,6}
print(set1 | set2)
print(set1 & set2)
print(set1 - set2)
print(set1 ^ set2)
# Out:
# {1, 2, 3, 4, 5, 6}
# {3}
# {1, 2}
# {1, 2, 4, 5, 6}

# %%
dictionary1={'name':'soz','age':22,'department':'db'}
print(dictionary1)
# Out:
# {'name': 'soz', 'age': 22, 'department': 'db'}

# %%
dictionary1.keys()
# Out:
# dict_keys(['name', 'age', 'department'])

# %%
dictionary1.items()
# Out:
# dict_items([('name', 'soz'), ('age', 22), ('department', 'db')])

# %%
dictionary1.values()
# Out:
# dict_values(['soz', 22, 'db'])

# %%
for n in dictionary1.values():
    print(n)
# Out:
# soz
# 22
# db

# %%
fruit=['pineaaple','apple','peach']
juice=['orange','limonade','apple_juice']

for one in fruit:
    for two in juice:
        print(one,'->',two)
# Out:
# pineaaple -> orange
# pineaaple -> limonade
# pineaaple -> apple_juice
# apple -> orange
# apple -> limonade
# apple -> apple_juice
# peach -> orange
# peach -> limonade
# peach -> apple_juice

# %%
n = 0

while n < 5:
    print(n)

    if n == 3:
        break

    n = n + 1
else:
    print("no")
# Out:
# 0
# 1
# 2
# 3

# %%
n = 0

while n < 5:
    print(n)

    if n == 3:
        continue

    n = n + 1
else:
    print("no")
# Out:
# 0
# 1
# 2
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# ...

# %%
n = 0

while n < 5:
    print(n)

    if n == 6:
        break

    n = n + 1
else:
    print("no")
# Out:
# 0
# 1
# 2
# 3
# 4
# no

# %%
n = 0

while n < 5:
    print(n)

    if n == 6:
        continue

    n = n + 1
else:
    print("no")
# Out:
# 0
# 1
# 2
# 3
# 4
# no

# %%
def function1(number,power):
    print(number**power)

function1(2,8)
# Out:
# 256

# %%
def function2(**n):
    print('number one: ' + n['int1'] + ' number two: ' + n['int2'])

function2(int1='200', int2='349')
# Out:
# number one: 200 number two: 349

# %%
x='7'
type(x)
# Out:
# str

# %%
conver=int(x)
type(convert)
# Out:
# int

# %%
type(x)
# Out:
# str

# %%
sum=convert+convert
print(sum)
# Out:
# 14

# %%
list1=[1,2,3]
type(list1)
# Out:
# list

# %%
tuple(list1)
type(tuple(list1))
# Out:
# tuple

# %%
set(list1)
type(set(list1))
# Out:
# set

# %%
dictionary1={'name':'soz','age':22,'department':'db'}
type(dictionary1)
# Out:
# dict

# %%
list(dictionary1.keys())
type(list(dictionary1.keys()))
# Out:
# list

# %%
long_string="""
koko is having bread and jam this lunch
"""
type(long_string)
# Out:
# str

# %%
set(long_string)
type(set(long_string))
# Out:
# set

# %%
list(long_string)
type(list(long_string))
# Out:
# list
