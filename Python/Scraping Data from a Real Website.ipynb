# %%
from bs4 import BeautifulSoup

# %%
import requests

# %%
url='https://en.wikipedia.org/wiki/List_of_largest_companies_in_the_United_States_by_revenue'

# %%
headers = {
    'User-Agent': 'Mozilla/5.0'
}

# %%
page = requests.get(url, headers=headers)

# %%
soup = BeautifulSoup(page.text, 'html.parser')

# %%
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-menu-disabled vector-feature-language-in-main-page-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-pinned-clientpref-1 skin-theme-clientpref-day vector-sticky-header-enabled vector-toc-available skin-thumbsize-clientpref-standard" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>List of largest companies in the United States by revenue - Wikipedia</title>
# ...

# %%
table = soup.find('table')
print(table)
# Out:
# <table class="wikitable sortable" id="mwOw">
# <caption id="mwPA"></caption>
# <tbody id="mwPQ"><tr id="mwPg"><th id="mwPw">Rank</th>
# <th id="mwQA">Name</th>
# <th id="mwQQ">Industry</th>
# <th id="mwQg">Revenue <br id="mwQw"/>(USD millions)</th>
# <th id="mwRA">Revenue growth</th>
# <th id="mwRQ">Employees</th>
# <th id="mwRg">Headquarters</th></tr>
# <tr id="mwRw">
# <td id="mwSA">1</td>
# <td id="mwSQ"><a href="https://en.wikipedia.org/wiki/Walmart" id="mwSg" rel="mw:WikiLink" title="Walmart">Walmart</a></td>
# <td id="mwSw">Retail</td>
# <td id="mwTA" style="text-align:center;">680,985</td>
# ...

# %%
table = soup.find('table', class_='wikitable sortable')

# %%
print(table)
# Out:
# <table class="wikitable sortable" id="mwOw">
# <caption id="mwPA"></caption>
# <tbody id="mwPQ"><tr id="mwPg"><th id="mwPw">Rank</th>
# <th id="mwQA">Name</th>
# <th id="mwQQ">Industry</th>
# <th id="mwQg">Revenue <br id="mwQw"/>(USD millions)</th>
# <th id="mwRA">Revenue growth</th>
# <th id="mwRQ">Employees</th>
# <th id="mwRg">Headquarters</th></tr>
# <tr id="mwRw">
# <td id="mwSA">1</td>
# <td id="mwSQ"><a href="https://en.wikipedia.org/wiki/Walmart" id="mwSg" rel="mw:WikiLink" title="Walmart">Walmart</a></td>
# <td id="mwSw">Retail</td>
# <td id="mwTA" style="text-align:center;">680,985</td>
# ...

# %%
world_titles=table.find_all('th')

# %%
world_table_titles=[title.text.strip() for title in world_titles]

# %%
print(world_table_titles)
# Out:
# ['Rank', 'Name', 'Industry', 'Revenue (USD millions)', 'Revenue growth', 'Employees', 'Headquarters']

# %%
#import pandas
import pandas as pd

# %%
df = pd.DataFrame(columns=world_table_titles)

# %%
print(df)
# Out:
# Empty DataFrame
# Columns: [Rank, Name, Industry, Revenue (USD millions), Revenue growth, Employees, Headquarters]
# Index: []

# %%
column_data = table.find_all('tr')

for row in column_data[1:]:
    row_data = row.find_all('td')
    individual_row_data = [data.text.strip() for data in row_data]

    length = len(df)
    df.loc[length] = individual_row_data

# %%
print(coloumn_data)
# Out:
# [<tr id="mwPg"><th id="mwPw">Rank</th>
# <th id="mwQA">Name</th>
# <th id="mwQQ">Industry</th>
# <th id="mwQg">Revenue <br id="mwQw"/>(USD millions)</th>
# <th id="mwRA">Revenue growth</th>
# <th id="mwRQ">Employees</th>
# <th id="mwRg">Headquarters</th></tr>, <tr id="mwRw">
# <td id="mwSA">1</td>
# <td id="mwSQ"><a href="https://en.wikipedia.org/wiki/Walmart" id="mwSg" rel="mw:WikiLink" title="Walmart">Walmart</a></td>
# <td id="mwSw">Retail</td>
# <td id="mwTA" style="text-align:center;">680,985</td>
# ...

# %%
df
# Out:
#    Rank                Name                    Industry  \
# 0     1             Walmart                      Retail
# 1     2              Amazon  Retail and cloud computing
# 2     3  UnitedHealth Group                  Healthcare
# 3     4               Apple                  Technology
# 4     5          CVS Health                  Healthcare
# ..  ...                 ...                         ...
# 95   96    General Dynamics       Aerospace and defense
# 96   97           Coca-Cola                    Beverage
# 97   98                TIAA                  Financials
# 98   99           Travelers                   Insurance
# 99  100           Eli Lilly              Pharmaceutical
#
#    Revenue (USD millions) Revenue growth  Employees              Headquarters
# 0                 680,985           5.1%  2,100,000     Bentonville, Arkansas
# 1                 637,959          11.0%  1,556,000       Seattle, Washington
# ...

# %%
df.to_csv(
    r'C:\Users\sozma\Downloads\data analyst course\python\companies.csv',
    index=False
)

# %%
import shutil

source = r"C:\Users\sozma\Downloads\data analyst course\python\companies.csv"

destination = r"C:\Users\sozma\Downloads\data analyst course\python\Scraping Data from a Real Website\companies.csv"

shutil.move(source, destination)
# Out:
# 'C:\\Users\\sozma\\Downloads\\data analyst course\\python\\Scraping Data from a Real Website\\companies.csv'
