# %%
import pandas as pd

# %%
df=pd.read_excel(r"C:\Users\sozma\OneDrive\Attachments\Documents\A1.data analyst course\pandas\Customer Call List.xlsx")

# %%
df=df.drop_duplicates()

# %%
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
df.columns
# Out:
# Index(['CustomerID', 'First_Name', 'Last_Name', 'Phone_Number', 'Address',
#        'Paying Customer', 'Do_Not_Contact', 'Not_Useful_Column'],
#       dtype='str')

# %%
df = df.drop(columns='Not_Useful_Column')

# %%
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
df["Last_Name"].str.strip()
# Out:
# 0         Baggins
# 1           Nadir
# 2          /White
# 3         Schrute
# 4            Snow
# 5         Swanson
# 6          Winger
# 7          Holmes
# 8             NaN
# 9          Parker
# 10         Gamgee
# 11      ...Potter
# 12         Draper
# 13          Knope
# 14    Flenderson_
# 15        Weasley
# 16          Scott
# 17           Kent
# 18         Braton
# 19      Skywalker
# Name: Last_Name, dtype: str

# %%
df["Last_Name"]=df["Last_Name"].str.strip()

# %%
df["Last_Name"]=df["Last_Name"].str.lstrip("...")

# %%
df["Last_Name"]=df["Last_Name"].str.rstrip("_")

# %%
df["Last_Name"]=df["Last_Name"].str.lstrip("/")

# %%
df["Last_Name"].str.strip()
# Out:
# 0        Baggins
# 1          Nadir
# 2          White
# 3        Schrute
# 4           Snow
# 5        Swanson
# 6         Winger
# 7         Holmes
# 8            NaN
# 9         Parker
# 10        Gamgee
# 11        Potter
# 12        Draper
# 13         Knope
# 14    Flenderson
# 15       Weasley
# 16         Scott
# 17          Kent
# 18        Braton
# 19     Skywalker
# Name: Last_Name, dtype: str

# %%
df["Phone_Number"] = df["Phone_Number"].astype(str)

# %%
df["Phone_Number"] = df["Phone_Number"].str.replace(r'[^0-9]', '', regex=True)

# %%
df["Phone_Number"] = df["Phone_Number"].apply(
    lambda x: x[0:3] + '-' + x[3:6] + '-' + x[6:10]
    if len(x) == 10 else x
)

# %%
df["Phone_Number"]=df["Phone_Number"].apply(lambda x:str(x))

# %%
df["Phone_Number"] = df["Phone_Number"].str.replace('NAN', ' ')

# %%
df["Phone_Number"].str.strip()
# Out:
# 0     123-545-5421
# 1     123-643-9775
# 3     123-543-2345
# 4     876-678-3469
# 5     304-762-2467
# 7     876-678-3469
# 9     123-545-5421
# 12    123-543-2345
# 13    876-678-3469
# 14    304-762-2467
# 15    123-545-5421
# 16    123-643-9775
# 19    876-678-3469
# Name: Phone_Number, dtype: str

# %%
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123-643-9775
# 2         1003     Walter       /White
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876-678-3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger
# 7         1008   Sherlock       Holmes  876-678-3469
# 8         1009    Gandalf          NaN
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee
# 11        1012      Harry    ...Potter
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876-678-3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123-643-9775
# 17        1018      Clark         Kent
# ...

# %%
df = df[df["Phone_Number"] != '']

# %%
df["Phone_Number"].str.strip()
# Out:
# 0     123-545-5421
# 1     123-643-9775
# 3     123-543-2345
# 4     876-678-3469
# 5     304-762-2467
# 7     876-678-3469
# 9     123-545-5421
# 12    123-543-2345
# 13    876-678-3469
# 14    304-762-2467
# 15    123-545-5421
# 16    123-643-9775
# 19    876-678-3469
# Name: Phone_Number, dtype: str

# %%
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123-643-9775
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876-678-3469
# 5         1006        Ron      Swanson  304-762-2467
# 7         1008   Sherlock       Holmes  876-678-3469
# 9         1010      Peter       Parker  123-545-5421
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876-678-3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123-643-9775
# 19        1020     Anakin    Skywalker  876-678-3469
#
#                                   Address Paying Customer Do_Not_Contact
# 0                   123 Shire Lane, Shire             Yes             No
# 1                     93 West Main Street              No            Yes
# ...

# %%
df[["Street_adress","state","zip_code"]]=df["Address"].str.split(',', n=1, expand=True)

# %%
df[["Street_address", "State", "Zip_code"]] = df["Address"].str.split(',', n=2, expand=True)

# %%
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123-643-9775
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876-678-3469
# 5         1006        Ron      Swanson  304-762-2467
# 7         1008   Sherlock       Holmes  876-678-3469
# 9         1010      Peter       Parker  123-545-5421
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876-678-3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123-643-9775
# 19        1020     Anakin    Skywalker  876-678-3469
#
#                                   Address Paying Customer Do_Not_Contact  \
# 0                   123 Shire Lane, Shire             Yes             No
# ...

# %%
df["Paying Customer"]=df["Paying Customer"].str.replace("Yes","Y")

# %%
df["Paying Customer"]=df["Paying Customer"].str.replace("No","N")

# %%
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123-643-9775
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876-678-3469
# 5         1006        Ron      Swanson  304-762-2467
# 7         1008   Sherlock       Holmes  876-678-3469
# 9         1010      Peter       Parker  123-545-5421
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876-678-3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123-643-9775
# 19        1020     Anakin    Skywalker  876-678-3469
#
#                                   Address Paying Customer Do_Not_Contact  \
# 0                   123 Shire Lane, Shire               Y             No
# ...

# %%
df["Do_Not_Contact"]=df["Do_Not_Contact"].str.replace("Yes","Y")

# %%
df["Do_Not_Contact"]=df["Do_Not_Contact"].str.replace("No","N")

# %%
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123-643-9775
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876-678-3469
# 5         1006        Ron      Swanson  304-762-2467
# 7         1008   Sherlock       Holmes  876-678-3469
# 9         1010      Peter       Parker  123-545-5421
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876-678-3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123-643-9775
# 19        1020     Anakin    Skywalker  876-678-3469
#
#                                   Address Paying Customer Do_Not_Contact  \
# 0                   123 Shire Lane, Shire               Y              N
# ...

# %%
df=df.replace('N/A',' ')

# %%
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123-643-9775
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876-678-3469
# 5         1006        Ron      Swanson  304-762-2467
# 7         1008   Sherlock       Holmes  876-678-3469
# 9         1010      Peter       Parker  123-545-5421
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876-678-3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123-643-9775
# 19        1020     Anakin    Skywalker  876-678-3469
#
#                                   Address Paying Customer Do_Not_Contact  \
# 0                   123 Shire Lane, Shire               Y              N
# ...

# %%
df = df.drop(columns=['Street_adress', 'state', 'zip_code'])

# %%
df.columns
# Out:
# Index(['CustomerID', 'First_Name', 'Last_Name', 'Phone_Number', 'Address',
#        'Paying Customer', 'Do_Not_Contact', 'Street_address', 'State',
#        'Zip_code'],
#       dtype='str')

# %%
df = df.drop(columns='Address')

# %%
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number Paying Customer  \
# 0         1001      Frodo      Baggins  123-545-5421               Y
# 1         1002       Abed        Nadir  123-643-9775               N
# 3         1004     Dwight      Schrute  123-543-2345               Y
# 4         1005        Jon         Snow  876-678-3469               Y
# 5         1006        Ron      Swanson  304-762-2467               Y
# 7         1008   Sherlock       Holmes  876-678-3469               N
# 9         1010      Peter       Parker  123-545-5421               Y
# 12        1013        Don       Draper  123-543-2345               Y
# 13        1014     Leslie        Knope  876-678-3469               Y
# 14        1015       Toby  Flenderson_  304-762-2467               N
# 15        1016        Ron      Weasley  123-545-5421               N
# 16        1017   Michael         Scott  123-643-9775               Y
# 19        1020     Anakin    Skywalker  876-678-3469               Y
#
# ...

# %%
df = df.reset_index(drop=True)

# %%
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number Paying Customer  \
# 0         1001      Frodo      Baggins  123-545-5421               Y
# 1         1002       Abed        Nadir  123-643-9775               N
# 2         1004     Dwight      Schrute  123-543-2345               Y
# 3         1005        Jon         Snow  876-678-3469               Y
# 4         1006        Ron      Swanson  304-762-2467               Y
# 5         1008   Sherlock       Holmes  876-678-3469               N
# 6         1010      Peter       Parker  123-545-5421               Y
# 7         1013        Don       Draper  123-543-2345               Y
# 8         1014     Leslie        Knope  876-678-3469               Y
# 9         1015       Toby  Flenderson_  304-762-2467               N
# 10        1016        Ron      Weasley  123-545-5421               N
# 11        1017   Michael         Scott  123-643-9775               Y
# 12        1020     Anakin    Skywalker  876-678-3469               Y
#
# ...

# %%
df["Last_Name"] = df["Last_Name"].str.replace('_', '', regex=False)

# %%
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number Paying Customer  \
# 0         1001      Frodo     Baggins  123-545-5421               Y
# 1         1002       Abed       Nadir  123-643-9775               N
# 2         1004     Dwight     Schrute  123-543-2345               Y
# 3         1005        Jon        Snow  876-678-3469               Y
# 4         1006        Ron     Swanson  304-762-2467               Y
# 5         1008   Sherlock      Holmes  876-678-3469               N
# 6         1010      Peter      Parker  123-545-5421               Y
# 7         1013        Don      Draper  123-543-2345               Y
# 8         1014     Leslie       Knope  876-678-3469               Y
# 9         1015       Toby  Flenderson  304-762-2467               N
# 10        1016        Ron     Weasley  123-545-5421               N
# 11        1017   Michael        Scott  123-643-9775               Y
# 12        1020     Anakin   Skywalker  876-678-3469               Y
#
# ...
