# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\sozma\OneDrive\Attachments\Documents\A1.data analyst course\pandas\countries of the world.csv")

# %%
df
# Out:
#              Country                               Region
# 0       Afghanistan         ASIA (EX. NEAR EAST)
# 1           Albania   EASTERN EUROPE
# 2           Algeria   NORTHERN AFRICA
# 3    American Samoa   OCEANIA
# 4           Andorra   WESTERN EUROPE
# ..               ...                                  ...
# 222       West Bank   NEAR EAST
# 223  Western Sahara   NORTHERN AFRICA
# 224           Yemen   NEAR EAST
# 225          Zambia   SUB-SAHARAN AFRICA
# 226        Zimbabwe   SUB-SAHARAN AFRICA
#
# [227 rows x 2 columns]

# %%
df2=pd.read_table(r"C:\Users\sozma\OneDrive\Attachments\Documents\A1.data analyst course\pandas\countries of the world.txt")

# %%
df2
# Out:
#              Country                               Region
# 0       Afghanistan         ASIA (EX. NEAR EAST)
# 1           Albania   EASTERN EUROPE
# 2           Algeria   NORTHERN AFRICA
# 3    American Samoa   OCEANIA
# 4           Andorra   WESTERN EUROPE
# ..               ...                                  ...
# 222       West Bank   NEAR EAST
# 223  Western Sahara   NORTHERN AFRICA
# 224           Yemen   NEAR EAST
# 225          Zambia   SUB-SAHARAN AFRICA
# 226        Zimbabwe   SUB-SAHARAN AFRICA
#
# [227 rows x 2 columns]

# %%
df3=pd.read_json(r"C:\Users\sozma\OneDrive\Attachments\Documents\A1.data analyst course\pandas\json_sample.json")

# %%
df3
# Out:
#                                            12 Strong  \
# 0  {'Genre': 'Action', 'Gross': '$453,173', 'IMDB...
#
#             A Fantastic Woman (Una Mujer Fantástica)  \
# 0  {'popcornscore': 83, 'rating': 'R', 'tomatosco...
#
#                           All The Money In The World  \
# 0  {'popcornscore': 71, 'rating': 'R', 'tomatosco...
#
#                           Bilal: A New Breed Of Hero  \
# 0  {'popcornscore': 91, 'rating': 'PG13', 'tomato...
#
#                                 Call Me By Your Name  \
# 0  {'popcornscore': 87, 'rating': 'R', 'tomatosco...
#
#                                         Darkest Hour  \
# 0  {'popcornscore': 84, 'rating': 'PG13', 'tomato...
#
#                                       Den Of Thieves  \
# 0  {'Genre': 'Action', 'Gross': '$491,898', 'IMDB...
#
#                                            Ferdinand  \
# 0  {'popcornscore': 49, 'rating': 'PG', 'tomatosc...
#
#                                   Fifty Shades Freed  \
# ...

# %%
df4=pd.read_excel(r"C:\Users\sozma\OneDrive\Attachments\Documents\A1.data analyst course\pandas\world_population_excel_workbook.xlsx")

# %%
df4
# Out:
#      Rank CCA3            Country           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara         El AaiÃºn    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0           41128771         38972230         33753499         28189672
# 1            2842321          2866849          2882481          2913399
# ...

# %%
pd.set_option('display.max_rows', 235)
pd.set_option('display.max_columns', 40)

# %%
print(df)
# Out:
#                                Country                               Region
# 0                         Afghanistan         ASIA (EX. NEAR EAST)
# 1                             Albania   EASTERN EUROPE
# 2                             Algeria   NORTHERN AFRICA
# 3                      American Samoa   OCEANIA
# 4                             Andorra   WESTERN EUROPE
# 5                              Angola   SUB-SAHARAN AFRICA
# 6                            Anguilla               LATIN AMER. & CARIB
# 7                   Antigua & Barbuda               LATIN AMER. & CARIB
# 8                           Argentina               LATIN AMER. & CARIB
# 9                             Armenia                  C.W. OF IND. STATES
# 10                              Aruba               LATIN AMER. & CARIB
# 11                          Australia   OCEANIA
# 12                            Austria   WESTERN EUROPE
# 13                         Azerbaijan                  C.W. OF IND. STATES
# ...

# %%
print(df2)
# Out:
#                                Country                               Region
# 0                         Afghanistan         ASIA (EX. NEAR EAST)
# 1                             Albania   EASTERN EUROPE
# 2                             Algeria   NORTHERN AFRICA
# 3                      American Samoa   OCEANIA
# 4                             Andorra   WESTERN EUROPE
# 5                              Angola   SUB-SAHARAN AFRICA
# 6                            Anguilla               LATIN AMER. & CARIB
# 7                   Antigua & Barbuda               LATIN AMER. & CARIB
# 8                           Argentina               LATIN AMER. & CARIB
# 9                             Armenia                  C.W. OF IND. STATES
# 10                              Aruba               LATIN AMER. & CARIB
# 11                          Australia   OCEANIA
# 12                            Austria   WESTERN EUROPE
# 13                         Azerbaijan                  C.W. OF IND. STATES
# ...

# %%
print(df3)
# Out:
#                                            12 Strong  \
# 0  {'Genre': 'Action', 'Gross': '$453,173', 'IMDB...
#
#             A Fantastic Woman (Una Mujer Fantástica)  \
# 0  {'popcornscore': 83, 'rating': 'R', 'tomatosco...
#
#                           All The Money In The World  \
# 0  {'popcornscore': 71, 'rating': 'R', 'tomatosco...
#
#                           Bilal: A New Breed Of Hero  \
# 0  {'popcornscore': 91, 'rating': 'PG13', 'tomato...
#
#                                 Call Me By Your Name  \
# 0  {'popcornscore': 87, 'rating': 'R', 'tomatosco...
#
#                                         Darkest Hour  \
# 0  {'popcornscore': 84, 'rating': 'PG13', 'tomato...
#
#                                       Den Of Thieves  \
# 0  {'Genre': 'Action', 'Gross': '$491,898', 'IMDB...
#
#                                            Ferdinand  \
# 0  {'popcornscore': 49, 'rating': 'PG', 'tomatosc...
#
#                                   Fifty Shades Freed  \
# ...

# %%
print(df4)
# Out:
#      Rank CCA3                           Country              Capital  \
# 0      36  AFG                       Afghanistan                Kabul
# 1     138  ALB                           Albania               Tirana
# 2      34  DZA                           Algeria              Algiers
# 3     213  ASM                    American Samoa            Pago Pago
# 4     203  AND                           Andorra     Andorra la Vella
# 5      42  AGO                            Angola               Luanda
# 6     224  AIA                          Anguilla           The Valley
# 7     201  ATG               Antigua and Barbuda       Saint Johnâ€™s
# 8      33  ARG                         Argentina         Buenos Aires
# 9     140  ARM                           Armenia              Yerevan
# 10    198  ABW                             Aruba           Oranjestad
# 11     55  AUS                         Australia             Canberra
# ...

# %%
df4.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Rank                         234 non-null    int64
#  1   CCA3                         234 non-null    str
#  2   Country                      234 non-null    str
#  3   Capital                      234 non-null    str
#  4   Continent                    234 non-null    str
#  5   2022 Population              234 non-null    int64
#  6   2020 Population              234 non-null    int64
#  7   2015 Population              234 non-null    int64
#  8   2010 Population              234 non-null    int64
#  9   2000 Population              234 non-null    int64
#  10  1990 Population              234 non-null    int64
#  11  1980 Population              234 non-null    int64
#  12  1970 Population              234 non-null    int64
# ...

# %%
df.shape
# Out:
# (227, 2)

# %%
df2.shape
# Out:
# (227, 2)

# %%
df3.shape
# Out:
# (1, 38)

# %%
df4.shape
# Out:
# (234, 17)

# %% [markdown]
# df.head()

# %%
df.head(10)
# Out:
#               Country                               Region
# 0        Afghanistan         ASIA (EX. NEAR EAST)
# 1            Albania   EASTERN EUROPE
# 2            Algeria   NORTHERN AFRICA
# 3     American Samoa   OCEANIA
# 4            Andorra   WESTERN EUROPE
# 5             Angola   SUB-SAHARAN AFRICA
# 6           Anguilla               LATIN AMER. & CARIB
# 7  Antigua & Barbuda               LATIN AMER. & CARIB
# 8          Argentina               LATIN AMER. & CARIB
# 9            Armenia                  C.W. OF IND. STATES

# %%
df2.head(10)
# Out:
#               Country                               Region
# 0        Afghanistan         ASIA (EX. NEAR EAST)
# 1            Albania   EASTERN EUROPE
# 2            Algeria   NORTHERN AFRICA
# 3     American Samoa   OCEANIA
# 4            Andorra   WESTERN EUROPE
# 5             Angola   SUB-SAHARAN AFRICA
# 6           Anguilla               LATIN AMER. & CARIB
# 7  Antigua & Barbuda               LATIN AMER. & CARIB
# 8          Argentina               LATIN AMER. & CARIB
# 9            Armenia                  C.W. OF IND. STATES

# %%
df3.head(10)
# Out:
#                                            12 Strong  \
# 0  {'Genre': 'Action', 'Gross': '$453,173', 'IMDB...
#
#             A Fantastic Woman (Una Mujer Fantástica)  \
# 0  {'popcornscore': 83, 'rating': 'R', 'tomatosco...
#
#                           All The Money In The World  \
# 0  {'popcornscore': 71, 'rating': 'R', 'tomatosco...
#
#                           Bilal: A New Breed Of Hero  \
# 0  {'popcornscore': 91, 'rating': 'PG13', 'tomato...
#
#                                 Call Me By Your Name  \
# 0  {'popcornscore': 87, 'rating': 'R', 'tomatosco...
#
#                                         Darkest Hour  \
# 0  {'popcornscore': 84, 'rating': 'PG13', 'tomato...
#
#                                       Den Of Thieves  \
# 0  {'Genre': 'Action', 'Gross': '$491,898', 'IMDB...
#
#                                            Ferdinand  \
# 0  {'popcornscore': 49, 'rating': 'PG', 'tomatosc...
#
#                                   Fifty Shades Freed  \
# ...

# %%
df4.head(10)
# Out:
#    Rank CCA3              Country           Capital      Continent  \
# 0    36  AFG          Afghanistan             Kabul           Asia
# 1   138  ALB              Albania            Tirana         Europe
# 2    34  DZA              Algeria           Algiers         Africa
# 3   213  ASM       American Samoa         Pago Pago        Oceania
# 4   203  AND              Andorra  Andorra la Vella         Europe
# 5    42  AGO               Angola            Luanda         Africa
# 6   224  AIA             Anguilla        The Valley  North America
# 7   201  ATG  Antigua and Barbuda    Saint Johnâ€™s  North America
# 8    33  ARG            Argentina      Buenos Aires  South America
# 9   140  ARM              Armenia           Yerevan           Asia
#
#    2022 Population  2020 Population  2015 Population  2010 Population  \
# 0         41128771         38972230         33753499         28189672
# 1          2842321          2866849          2882481          2913399
# ...

# %%
df.tail(10)
# Out:
#                 Country                               Region
# 217            Vanuatu   OCEANIA
# 218          Venezuela               LATIN AMER. & CARIB
# 219            Vietnam         ASIA (EX. NEAR EAST)
# 220     Virgin Islands               LATIN AMER. & CARIB
# 221  Wallis and Futuna   OCEANIA
# 222          West Bank   NEAR EAST
# 223     Western Sahara   NORTHERN AFRICA
# 224              Yemen   NEAR EAST
# 225             Zambia   SUB-SAHARAN AFRICA
# 226           Zimbabwe   SUB-SAHARAN AFRICA

# %%
df2.tail(10)
# Out:
#                 Country                               Region
# 217            Vanuatu   OCEANIA
# 218          Venezuela               LATIN AMER. & CARIB
# 219            Vietnam         ASIA (EX. NEAR EAST)
# 220     Virgin Islands               LATIN AMER. & CARIB
# 221  Wallis and Futuna   OCEANIA
# 222          West Bank   NEAR EAST
# 223     Western Sahara   NORTHERN AFRICA
# 224              Yemen   NEAR EAST
# 225             Zambia   SUB-SAHARAN AFRICA
# 226           Zimbabwe   SUB-SAHARAN AFRICA

# %%
df3.tail(10)
# Out:
#                                            12 Strong  \
# 0  {'Genre': 'Action', 'Gross': '$453,173', 'IMDB...
#
#             A Fantastic Woman (Una Mujer Fantástica)  \
# 0  {'popcornscore': 83, 'rating': 'R', 'tomatosco...
#
#                           All The Money In The World  \
# 0  {'popcornscore': 71, 'rating': 'R', 'tomatosco...
#
#                           Bilal: A New Breed Of Hero  \
# 0  {'popcornscore': 91, 'rating': 'PG13', 'tomato...
#
#                                 Call Me By Your Name  \
# 0  {'popcornscore': 87, 'rating': 'R', 'tomatosco...
#
#                                         Darkest Hour  \
# 0  {'popcornscore': 84, 'rating': 'PG13', 'tomato...
#
#                                       Den Of Thieves  \
# 0  {'Genre': 'Action', 'Gross': '$491,898', 'IMDB...
#
#                                            Ferdinand  \
# 0  {'popcornscore': 49, 'rating': 'PG', 'tomatosc...
#
#                                   Fifty Shades Freed  \
# ...

# %%
df4.tail(3)
# Out:
#      Rank CCA3   Country Capital Continent  2022 Population  2020 Population  \
# 231    46  YEM     Yemen   Sanaa      Asia         33696614         32284046
# 232    63  ZMB    Zambia  Lusaka    Africa         20017675         18927715
# 233    74  ZWE  Zimbabwe  Harare    Africa         16320537         15669666
#
#      2015 Population  2010 Population  2000 Population  1990 Population  \
# 231         28516545         24743946         18628700         13375121
# 232         16248230         13792086          9891136          7686401
# 233         14154937         12839771         11834676         10113893
#
#      1980 Population  1970 Population  Area (kmÂ²)  Density (per kmÂ²)  \
# 231          9204938          6843607       527968             63.8232
# 232          5720438          4281671       752612             26.5976
# 233          7049926          5202918       390757             41.7665
#
#      Growth Rate  World Population Percentage
# ...

# %%
print(df2['Region'])
# Out:
# 0            ASIA (EX. NEAR EAST)
# 1      EASTERN EUROPE
# 2      NORTHERN AFRICA
# 3      OCEANIA
# 4      WESTERN EUROPE
# 5      SUB-SAHARAN AFRICA
# 6                  LATIN AMER. & CARIB
# 7                  LATIN AMER. & CARIB
# 8                  LATIN AMER. & CARIB
# 9                     C.W. OF IND. STATES
# 10                 LATIN AMER. & CARIB
# 11     OCEANIA
# 12     WESTERN EUROPE
# 13                    C.W. OF IND. STATES
# 14                 LATIN AMER. & CARIB
# 15     NEAR EAST
# 16           ASIA (EX. NEAR EAST)
# 17                 LATIN AMER. & CARIB
# 18                    C.W. OF IND. STATES
# 19     WESTERN EUROPE
# 20                 LATIN AMER. & CARIB
# 21     SUB-SAHARAN AFRICA
# 22     NORTHERN AMERICA
# 23           ASIA (EX. NEAR EAST)
# 24                 LATIN AMER. & CARIB
# 25     EASTERN EUROPE
# 26     SUB-SAHARAN AFRICA
# 27                 LATIN AMER. & CARIB
# 28                 LATIN AMER. & CARIB
# 29           ASIA (EX. NEAR EAST)
# ...

# %%
df2.columns
# Out:
# Index(['Country', 'Region'], dtype='str')

# %%
df2.shape
# Out:
# (227, 2)

# %%
df2.loc[225]
# Out:
# Country                                Zambia
# Region     SUB-SAHARAN AFRICA
# Name: 225, dtype: str

# %%
df2.iloc[2]
# Out:
# Country                               Algeria
# Region     NORTHERN AFRICA
# Name: 2, dtype: str
